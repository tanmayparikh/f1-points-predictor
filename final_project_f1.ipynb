# %% [markdown]
# # Computational Statistics Final Project

# %%
import sqlite3
import pandas as pd

# %%
con = sqlite3.connect("f1.sql")

# %%
df = pd.read_sql_query("SELECT * FROM races WHERE year=2010", con)

df.head()
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0     337  2010      1          3     Bahrain Grand Prix  2010-03-14
# 1     338  2010      2          1  Australian Grand Prix  2010-03-28
# 2     339  2010      3          2   Malaysian Grand Prix  2010-04-04
# 3     340  2010      4         17     Chinese Grand Prix  2010-04-18
# 4     341  2010      5          4     Spanish Grand Prix  2010-05-09
#
#        time                                                url fp1_date  \
# 0  12:00:00  http://en.wikipedia.org/wiki/2010_Bahrain_Gran...     None
# 1  06:00:00  http://en.wikipedia.org/wiki/2010_Australian_G...     None
# 2  08:00:00  http://en.wikipedia.org/wiki/2010_Malaysian_Gr...     None
# 3  06:00:00  http://en.wikipedia.org/wiki/2010_Chinese_Gran...     None
# 4  12:00:00  http://en.wikipedia.org/wiki/2010_Spanish_Gran...     None
#
#   fp1_time fp2_date fp2_time fp3_date fp3_time quali_date quali_time  \
# ...
